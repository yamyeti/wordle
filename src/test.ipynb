# %%
from player.inverted_index import InvertedIndex
from player.inverted_intersect import InvertedIntersect
from player.wordle_scorer import WordleGuessScorer
from collections import Counter

from game.wordle import Wordle

# %%
game = Wordle()
inv_index = InvertedIndex()
inv_intersect = InvertedIntersect()

# %%
game.set_word_of_the_day('plait')
res = game.guess('pares')

# %%
words_list = game.get_wordle_words()
inv_index.index(words_list)

scorer = WordleGuessScorer(words_list)
scorer.get_best_guess(scoring_method='zipf')
# Out:
# ['pares']

# %%
scorer.count_words()
# Out:
# 14855

# %%
# scorer.calculate_word_scores()
# scorer.calculate_zipf_idf()

# %%
scorer.idf['paris']
# Out:
# 1.4034371396879424

# %%
scorer.idf['pares']
# Out:
# 4.991755732936075

# %%
scorer.scores
# Out:
# {'pares': 18.50159,
#  'tares': 19.16659,
#  'soare': 19.39029,
#  'sared': 19.43099,
#  'bares': 19.46621,
#  'pores': 19.48426,
#  'cares': 19.52781,
#  'mares': 19.59118,
#  'lares': 19.93799,
#  'panes': 19.99146,
#  'dares': 20.13207,
#  'tores': 20.14926,
#  'saner': 20.31413,
#  'saine': 20.36944,
#  'pales': 20.37574,
#  'sored': 20.41366,
#  'ranes': 20.44196,
#  'bores': 20.44888,
#  'nares': 20.4865,
#  'seria': 20.49192,
#  'cores': 20.51048,
#  'sorel': 20.54032,
#  'mores': 20.57385,
#  'reais': 20.7001,
#  'rales': 20.82624,
#  'teras': 20.87622,
#  'gares': 20.87763,
#  'braes': 20.88083,
#  'pates': 20.887,
#  'lores': 20.92066,
#  'saned': 20.92086,
#  'peats': 20.9382,
#  'banes': 20.95608,
#  'pones': 20.97413,
#  'canes': 21.01768,
#  'tales': 21.04074,
#  'manes': 21.08105,
#  'salet': 21.10025,
#  'dores': 21.11474,
#  'porae': 21.11941,
#  'hares': 21.16624,
#  'pears': 21.20663,
#  'sater': 21.20967,
#  'fares': 21.2354,
#  'peals': 21.24804,
#  'seral': 21.26728,
#  'strae': 21.32198,
#  'paris': 21.33139,
#  'rates': 21.3375,
#  'bales': 21.34036,
#  'slate': 21.34296,
#  'peans': 21.35572,
#  'poles': 21.35841,
#  'toeas': 21.4008,
#  'peris': 21.42439,
#  'rones': 21.42463,
#  'lanes': 21.42786,
#  'aures': 21.43573,
#  'serai': 21.43636,
#  'parse': 21.44469,
#  'tires': 21.45429,
#  'males': 21.46533,
#  'blaes': 21.49519,
#  'claes': 21.55679,
#  'aeros': 21.62683,
#  'tones': 21.63913,
#  'soler': 21.68108,
#  'reals': 21.69854,
#  'sired': 21.71869,
#  'pries': 21.72894,
#  'pareo': 21.73337,
#  'wares': 21.73514,
#  'pures': 21.74739,
#  'slane': 21.76048,
#  'toras': 21.76589,
#  'saree': 21.79558,
#  'reans': 21.80622,
#  'roles': 21.80891,
#  'cires': 21.81551,
#  'sated': 21.8164,
#  'saute': 21.83615,
#  'sarge': 21.84453,
#  'bates': 21.85162,
#  'gores': 21.8603,
#  'potes': 21.86967,
#  'seres': 21.87006,
#  'tears': 21.87163,
#  'mires': 21.87888,
#  'beats': 21.90282,
#  'teals': 21.91304,
#  'cates': 21.91322,
#  'bones': 21.93875,
#  'mates': 21.97659,
#  'cones': 22.00035,
#  'dales': 22.00622,
#  'parts': 22.01999,
#  'toles': 22.02341,
#  'meats': 22.02779,
#  'siren': 22.03081,
#  'parte': 22.03851,
#  'boras': 22.06551,
#  'sorta': 22.07019,
#  'stoae': 22.07105,
#  'paise': 22.08263,
#  'pelas': 22.08537,
#  'tarse': 22.10969,
#  'perts': 22.11299,
#  'vares': 22.11479,
#  'paces': 22.12427,
#  'aloes': 22.14277,
#  'pared': 22.15552,
#  'soral': 22.15695,
#  'bears': 22.17125,
#  'moras': 22.19048,
#  'spaer': 22.20054,
#  'morae': 22.209,
#  'beals': 22.21266,
#  'fores': 22.21807,
#  'moais': 22.22886,
#  'snare': 22.24713,
#  'rames': 22.25935,
#  'pines': 22.27916,
#  'soled': 22.28781,
#  'roate': 22.29689,
#  'earls': 22.29857,
#  'stare': 22.31739,
#  'rotes': 22.32017,
#  'beans': 22.32034,
#  'boles': 22.32303,
#  'kaies': 22.33498,
#  'meals': 22.33763,
#  'plies': 22.3433,
#  'parle': 22.34835,
#  'stale': 22.3588,
#  'leats': 22.3746,
#  'coles': 22.38463,
#  'tries': 22.39394,
#  'earns': 22.40625,
#  'perls': 22.42283,
#  'means': 22.44531,
#  'moles': 22.448,
#  'scrae': 22.44983,
#  'roues': 22.45693,
#  'stane': 22.46648,
#  'paren': 22.46764,
#  'carse': 22.47091,
#  'tames': 22.47385,
#  'samey': 22.49912,
#  'pages': 22.50605,
#  'saice': 22.50939,
#  'taros': 22.51049,
#  'meris': 22.51398,
#  'dates': 22.51748,
#  'perns': 22.53051,
#  'raise': 22.53313,
#  'marse': 22.53428,
#  'rapes': 22.56858,
#  'soave': 22.57176,
#  'sarin': 22.57291,
#  'races': 22.57477,
#  'solei': 22.58355,
#  'taels': 22.62974,
#  'poets': 22.63757,
#  'lears': 22.64303,
#  'paseo': 22.6528,
#  'arles': 22.65349,
#  'piles': 22.66344,
#  'serin': 22.66591,
#  'slier': 22.66597,
#  'yores': 22.67154,
#  'sured': 22.67679,
#  'kores': 22.67971,
#  'spate': 22.69026,
#  'bries': 22.69356,
#  'roans': 22.69589,
#  'fanes': 22.72527,
#  'rines': 22.72966,
#  'apres': 22.741,
#  'ayres': 22.74593,
#  'gales': 22.75178,
#  'cries': 22.75516,
#  'sores': 22.75973,
#  'laris': 22.76779,
#  'cures': 22.77361,
#  'sarod': 22.77489,
#  'soree': 22.77825,
#  'tapes': 22.78308,
#  'taces': 22.78927,
#  'pomes': 22.79152,
#  'leans': 22.79212,
#  'boats': 22.79249,
#  'spaed': 22.80727,
#  'tared': 22.82052,
#  'sager': 22.82872,
#  'cades': 22.83265,
#  'botes': 22.83429,
#  'cames': 22.83507,
#  'mures': 22.83698,
#  'dears': 22.83711,
#  'salep': 22.84704,
#  'coats': 22.85409,
#  'prase': 22.85931,
#  'samel': 22.86491,
#  'nates': 22.87191,
#  'coate': 22.87261,
#  'deals': 22.87852,
#  'salue': 22.8818,
#  'share': 22.89257,
#  'cotes': 22.89589,
#  'porey': 22.89906,
#  'sonar': 22.91343,
#  'penis': 22.91426,
#  'moats': 22.91746,
#  'neats': 22.92311,
#  'aunes': 22.9256,
#  'pairs': 22.92636,
#  'baels': 22.92936,
#  'shale': 22.93398,
#  'tines': 22.94416,
#  'paire': 22.94488,
#  'rages': 22.95655,
#  'pleas': 22.9569,
#  'paste': 22.95794,
#  'spare': 22.95869,
#  'motes': 22.95926,
#  'daris': 22.96187,
#  'ceros': 22.96471,
#  'pails': 22.96777,
#  'aeons': 22.96792,
#  'caret': 22.97685,
#  'siler': 22.98611,
#  'deans': 22.9862,
#  'doles': 22.98889,
#  'spale': 23.0001,
#  'ports': 23.00266,
#  'porte': 23.02118,
#  'sayer': 23.03735,
#  'hales': 23.04039,
#  'carts': 23.04621,
#  'slade': 23.04791,
#  'samen': 23.05037,
#  'pyres': 23.05759,
#  'boars': 23.06092,
#  'serac': 23.06124,
#  'carte': 23.06473,
#  'poise': 23.0653,
#  'pains': 23.07545,
#  'torse': 23.09236,
#  'saber': 23.093,
#  'reads': 23.09365,
#  'moues': 23.09602,
#  'tarns': 23.10251,
#  'spane': 23.10778,
#  'raits': 23.10843,
#  'fales': 23.10955,
#  'marts': 23.10958,
#  'riles': 23.11394,
#  'bared': 23.12014,
#  'taser': 23.13322,
#  'pored': 23.13819,
#  'certs': 23.13921,
#  'capes': 23.1443,
#  'coals': 23.16393,
#  'sorex': 23.16753,
#  'peins': 23.16845,
#  'maise': 23.17222,
#  'melas': 23.17496,
#  'seron': 23.18001,
#  'cared': 23.18174,
#  'lures': 23.18379,
#  'moars': 23.18589,
#  'kanes': 23.18691,
#  'nears': 23.19154,
#  'terns': 23.19551,
#  'suite': 23.19772,
#  'sacre': 23.20509,
#  'palis': 23.20554,
#  'mapes': 23.20767,
#  'sined': 23.20856,
#  'maces': 23.21386,
#  'ioras': 23.22074,
#  'wanes': 23.22501,
#  'moals': 23.2273,
#  'acres': 23.22755,
#  'neals': 23.23295,
#  'rodes': 23.2396,
#  'lades': 23.24283,
#  'bines': 23.24378,
#  'lames': 23.24525,
#  'saker': 23.2502,
#  'praos': 23.26011,
#  'paves': 23.26067,
#  'gates': 23.26304,
#  'sanes': 23.26693,
#  'peaks': 23.27128,
#  'ranis': 23.27176,
#  'peons': 23.27958,
#  'eorls': 23.28124,
#  'solar': 23.29771,
#  'cines': 23.30538,
#  'lotes': 23.30607,
#  'teads': 23.30815,
#  'geats': 23.31424,
#  'satem': 23.31593,
#  'naris': 23.3163,
#  'tiles': 23.32844,
#  'moans': 23.33498,
#  'noles': 23.34332,
#  'carls': 23.35605,
#  'dries': 23.35942,
#  'laers': 23.35973,
#  'senes': 23.35993,
#  'mines': 23.36875,
#  'clies': 23.36952,
#  'carle': 23.37457,
#  'dures': 23.37787,
#  'rakes': 23.37803,
#  'ranse': 23.38506,
#  'oared': 23.3945,
#  'barns': 23.40213,
#  'rails': 23.41827,
#  'marls': 23.41942,
#  'porns': 23.42018,
#  'paler': 23.42294,
#  'baser': 23.43284,
#  'prats': 23.43461,
#  'tabes': 23.43533,
#  'raile': 23.43679,
#  'marle': 23.43794,
#  'dames': 23.43933,
#  'seity': 23.4412,
#  'scare': 23.44524,
#  'poser': 23.45089,
#  'prate': 23.45313,
#  'corse': 23.45358,
#  'hires': 23.45394,
#  'sawer': 23.45577,
#  'tomes': 23.45652,
#  'proas': 23.4567,
#  'doats': 23.45835,
#  'carns': 23.46373,
#  'peags': 23.46875,
#  'goras': 23.47693,
#  'carne': 23.48225,
#  'scale': 23.48665,
#  'sonde': 23.49147,
#  'caser': 23.49444,
#  'dotes': 23.50015,
#  'potae': 23.50482,
#  'pants': 23.50986,
#  'merls': 23.51242,
#  'morse': 23.51695,
#  'fires': 23.5231,
#  'rased': 23.52545,
#  'rains': 23.52595,
#  'cages': 23.53227,
#  'reaps': 23.53873,
#  'raine': 23.54447,
#  'pians': 23.55042,
#  'ropes': 23.55125,
#  'hates': 23.55165,
#  'maser': 23.55781,
#  'laces': 23.56067,
#  'betas': 23.56125,
#  'yales': 23.56302,
#  'twaes': 23.56742,
#  'deros': 23.56897,
#  'kales': 23.57119,
#  'amies': 23.57948,
#  'gears': 23.58267,
#  'saver': 23.58334,
#  'pareu': 23.58423,
#  'safer': 23.59223,
#  'takes': 23.59253,
#  'siled': 23.59284,
#  'mages': 23.59564,
#  'beaus': 23.59649,
#  'boets': 23.60219,
#  'heats': 23.60285,
#  'pents': 23.60286,
#  'vanes': 23.60466,
#  'beads': 23.60777,
#  'wales': 23.60929,
#  'reins': 23.61895,
#  'fates': 23.62081,
#  'pules': 23.62154,
#  'baits': 23.62255,
#  'geals': 23.62408,
#  'phies': 23.62448,
#  'rites': 23.6252,
#  'biles': 23.62806,
#  'tails': 23.63277,
#  'sease': 23.63837,
#  'hones': 23.63878,
#  'tolas': 23.64004,
#  'sayed': 23.64408,
#  'paned': 23.64539,
#  'darts': 23.65047,
#  'sales': 23.65121,
#  'setal': 23.65269,
#  'skate': 23.6555,
#  'feats': 23.67201,
#  'slake': 23.67604,
#  'bayes': 23.6793,
#  'psoae': 23.68009,
#  'monas': 23.68035,
#  'loans': 23.68179,
#  'metas': 23.68622,
#  'runes': 23.68776,
#  'paxes': 23.69086,
#  'eards': 23.69368,
#  'sabed': 23.69973,
#  'garis': 23.70743,
#  'fones': 23.70794,
#  'raves': 23.71117,
#  'lines': 23.71556,
#  'reaks': 23.72178,
#  'tyres': 23.72259,
#  'noias': 23.72374,
#  'pards': 23.72494,
#  'teils': 23.72577,
#  'toise': 23.7303,
#  'geans': 23.73176,
#  'meads': 23.73274,
#  'goles': 23.73445,
#  'tased': 23.73995,
#  'tains': 23.74045,
#  'seles': 23.74421,
#  'loris': 23.75046,
#  'senor': 23.75103,
#  'miles': 23.75303,
#  'bodes': 23.75372,
#  'stade': 23.75391,
#  'daces': 23.75475,
#  'peasy': 23.75918,
#  'horas': 23.76554,
#  'topes': 23.76575,
#  'janes': 23.76633,
#  'panel': 23.77205,
#  'sorda': 23.77514,
#  'aides': 23.78247,
#  'names': 23.79376,
#  'saint': 23.79996,
#  'slaes': 23.80604,
#  'soger': 23.81139,
#  'codes': 23.81532,
#  'comes': 23.81774,
#  'posey': 23.81849,
#  'palet': 23.82478,
#  'teins': 23.83345,
#  'reams': 23.83798,
#  'liras': 23.84232,
#  'sabre': 23.85115,
#  'poset': 23.85273,
#  'notes': 23.85458,
#  'mabes': 23.85992,
#  'acies': 23.86549,
#  'boers': 23.87062,
#  'hears': 23.87128,
#  'larns': 23.87391,
#  'solde': 23.87575,
#  'modes': 23.87869,
#  'renos': 23.87886,
#  'benis': 23.87888,
#  'bakes': 23.89215,
#  'sable': 23.89256,
#  'rials': 23.89324,
#  'pinas': 23.89579,
#  'tunes': 23.90226,
#  'laser': 23.90462,
#  'silen': 23.90496,
#  'snied': 23.90844,
#  'dines': 23.90964,
#  'pokes': 23.9102,
#  'manis': 23.91085,
#  'heals': 23.91269,
#  'shred': 23.91594,
#  'baste': 23.92256,
#  'corey': 23.92528,
#  'poire': 23.92755,
#  'manie': 23.92937,
#  'bails': 23.93239,
#  'arets': 23.93265,
#  'pater': 23.9342,
#  'teaks': 23.93628,
#  'rotas': 23.9368,
#  'bolas': 23.93966,
#  'fears': 23.94044,
#  'poste': 23.94061,
#  'piets': 23.9426,
#  'doris': 23.94454,
#  'sayne': 23.94459,
#  'razes': 23.94589,
#  'shier': 23.94715,
#  'baile': 23.95091,
#  'savey': 23.95094,
#  'cakes': 23.95375,
#  'darls': 23.96031,
#  'rants': 23.96036,
#  'pause': 23.96686,
#  'borts': 23.96728,
#  'stied': 23.9787,
#  'feals': 23.98185,
#  'spred': 23.98206,
#  'sware': 23.98324,
#  'roads': 23.98332,
#  'caste': 23.98416,
#  'stear': 23.98557,
#  'pelts': 23.98714,
#  'vales': 23.98894,
#  'moers': 23.99559,
#  'airts': 23.99603,
#  'colas': 24.00126,
#  'spier': 24.01327,
#  'mairs': 24.01595,
#  'santo': 24.01711,
#  'makes': 24.01712,
#  'byres': 24.02221,
#  'wires': 24.02284,
#  'holes': 24.02306,
#  'manse': 24.02415,
#  'swale': 24.02465,
#  'paled': 24.02967,
#  'maire': 24.03447,
#  'based': 24.03957,
#  'plats': 24.04897,
#  'teams': 24.05248,
#  'rents': 24.05336,
#  'mails': 24.05736,
#  'posed': 24.05762,
#  'dorse': 24.05784,
#  'shoer': 24.05828,
#  'sawed': 24.0625,
#  'molas': 24.06463,
#  'sires': 24.06476,
#  'caner': 24.06488,
#  'tiars': 24.06633,
#  'plate': 24.06749,
#  'darns': 24.06799,
#  'rules': 24.07204,
#  'yates': 24.07428,
#  'rhies': 24.07498,
#  'sober': 24.07567,
#  'maile': 24.07588,
#  'genas': 24.07713,
#  'seamy': 24.07775,
#  'leads': 24.07955,
#  'siree': 24.08328,
#  'tiare': 24.08485,
#  'ceils': 24.08699,
#  'taler': 24.08794,
#  'surat': 24.08853,
#  'morts': 24.09225,
#  'raned': 24.09589,
#  'nerts': 24.0979,
#  'cased': 24.10117,
#  'cains': 24.10167,
#  'bored': 24.10281,
#  'napes': 24.10299,
#  'sited': 24.1041,
#  'sepia': 24.10841,
#  'copes': 24.12697,
#  'stire': 24.13012,
#  'aired': 24.13156,
#  'beins': 24.13307,
#  'bites': 24.13932,
#  'rajes': 24.14094,
#  'raxes': 24.14136,
#  'meils': 24.15036,
#  'baons': 24.1512,
#  'toges': 24.15372,
#  'perai': 24.16089,
#  'derns': 24.16099,
#  'sates': 24.16247,
#  'cored': 24.16441,
#  'mased': 24.16454,
#  'mains': 24.16504,
#  'snore': 24.17099,
#  'stile': 24.17153,
#  'farse': 24.1785,
#  'poake': 24.17947,
#  'gades': 24.18247,
#  'games': 24.18489,
#  'polis': 24.18821,
#  'saved': 24.19007,
#  'mopes': 24.19034,
#  'toads': 24.19782,
#  'safed': 24.19896,
#  'cites': 24.20092,
#  'robes': 24.2035,
#  'goats': 24.20391,
#  'orles': 24.20413,
#  'piers': 24.21103,
#  'seats': 24.21367,
#  'tians': 24.21542,
#  'solan': 24.21656,
#  'bosie': 24.21663,
#  'donas': 24.22124,
#  'lodes': 24.2255,
#  'plues': 24.22753,
#  'lomes': 24.22792,
#  'socle': 24.22917,
#  'borel': 24.22947,
#  'beaks': 24.2359,
#  'store': 24.24125,
#  'ceria': 24.24267,
#  'reast': 24.24392,
#  'sones': 24.2496,
#  'meins': 24.25804,
#  'relos': 24.26314,
#  'mites': 24.26429,
#  'auris': 24.26553,
#  'seric': 24.27441,
#  'trues': 24.27817,
#  'repas': 24.27821,
#  'cosie': 24.27823,
#  'stole': 24.28266,
#  'tules': 24.28654,
#  'caves': 24.28689,
#  'slaid': 24.28977,
#  'malis': 24.29513,
#  'cafes': 24.29578,
#  'koras': 24.29634,
#  'pilae': 24.29859,
#  'noris': 24.29897,
#  'syren': 24.29911,
#  'roset': 24.30323,
#  'stria': 24.30869,
#  'snake': 24.31178,
#  'norie': 24.31749,
#  'haets': 24.31955,
#  'petos': 24.3239,
#  'buras': 24.32864,
#  'shade': 24.32909,
#  'sonce': 24.34399,
#  'lenis': 24.35066,
#  'basen': 24.35169,
#  'beams': 24.3521,
#  'peaty': 24.353,
#  'parks': 24.35307,
#  'morel': 24.35444,
#  'tajes': 24.35544,
#  'taxes': 24.35586,
#  'naieo': 24.35622,
#  'arise': 24.36038,
#  'rokes': 24.3607,
#  'meaks': 24.36087,
#  'lairs': 24.36276,
#  'lakes': 24.36393,
#  'crias': 24.37179,
#  'soras': 24.37636,
#  'canoe': 24.3801,
#  'stake': 24.38204,
#  'baler': 24.38756,
#  'poney': 24.38893,
#  'stair': 24.38904,
#  'tards': 24.38994,
#  'stone': 24.39034,
#  'sauce': 24.39362,
#  'years': 24.39391,
#  'spade': 24.39521,
#  'abies': 24.39721,
#  'brats': 24.39923,
#  'roils': 24.40094,
#  'salto': 24.40139,
#  'vires': 24.40249,
#  'borne': 24.40332,
#  'poler': 24.40561,
#  'pomas': 24.40815,
#  'airns': 24.41355,
#  'antes': 24.41485,
#  'sider': 24.4168,
#  'sural': 24.42008,
#  'domes': 24.422,
#  'manos': 24.42495,
#  'elans': 24.43523,
#  'shite': 24.43687,
#  'blase': 24.43829,
#  'sower': 24.43844,
#  'wears': 24.44018,
#  'perks': 24.44607,
#  'corns': 24.4464,
#  'botas': 24.45092,
#  'muras': 24.45361,
#  'pilea': 24.4555,
#  'leirs': 24.45576,
#  'fries': 24.46275,
#  'plans': 24.46649,
#  'naios': 24.46834,
#  'parms': 24.46927,
#  'hades': 24.47108,
#  'arose': 24.47151,
#  'hames': 24.4735,
#  'bants': 24.47448,
#  'telos': 24.47764,
#  'crate': 24.47935,
#  'pebas': 24.47996,
#  'weals': 24.48159,
#  'sears': 24.4821,
#  'bemas': 24.4831,
#  'plane': 24.48501,
#  'nages': 24.49096,
#  'ponts': 24.49253,
#  'tepas': 24.49271,
#  'lyres': 24.49399,
#  'gapes': 24.49412,
#  'oaves': 24.49965,
#  'seare': 24.50062,
#  'spite': 24.50299,
#  'rohes': 24.50531,
#  'rosed': 24.50812,
#  'roins': 24.50862,
#  'morns': 24.50977,
#  'haros': 24.51014,
#  'selah': 24.51073,
#  'lased': 24.51135,
#  'goals': 24.51375,
#  'trans': 24.51713,
#  'breis': 24.52033,
#  'snead': 24.52204,
#  'seals': 24.52351,
#  'leaps': 24.52463,
#  'morne': 24.52829,
#  'manet': 24.53009,
#  'cants': 24.53608,
#  'doers': 24.53648,
#  'lopes': 24.53715,
#  'segar': 24.53835,
#  'fades': 24.54024,
#  'pated': 24.54093,
#  'blaer': 24.54239,
#  'fames': 24.54266,
#  'yeans': 24.543,
#  'rides': 24.54463,
#  'denis': 24.54474,
#  'rimes': 24.54705,
#  'pynes': 24.54746,
#  'shote': 24.548,
#  'shied': 24.55388,
#  'shear': 24.56075,
#  'tinas': 24.56079,
#  'perms': 24.56227,
#  'danse': 24.56504,
#  'bents': 24.56748,
#  'parge': 24.56906,
#  'froes': 24.57388,
#  'tokes': 24.5752,
#  'puris': 24.57719,
#  'parcs': 24.57746,
#  'faros': 24.5793,
#  'stage': 24.57951,
#  'netas': 24.58154,
#  'salty': 24.58441,
#  'mazes': 24.58498,
#  'weans': 24.58927,
#  'beray': 24.59064,
#  'stead': 24.5923,
#  'peres': 24.59459,
#  'mants': 24.59945,
#  'slain': 24.60189,
#  'heros': 24.60314,
#  'saris': 24.60686,
#  'baned': 24.61001,
#  'lites': 24.6111,
#  'toils': 24.61544,
#  'pirls': 24.61753,
#  'mante': 24.61797,
#  'spied': 24.62,
#  'boite': 24.62374,
#  'spear': 24.62687,
#  'hoaed': 24.62805,
#  'cents': 24.62908,
#  'roake': 24.62997,
#  'seans': 24.63119,
#  'dorts': 24.63314,
#  'soles': 24.63388,
#  'toile': 24.63396,
#  'padis': 24.63623,
#  'salve': 24.63803,
#  'crues': 24.63939,
#  'soily': 24.64071,
#  'eyras': 24.64296,
#  'peart': 24.65567,
#  'shoed': 24.66501,
#  'coits': 24.66682,
#  'patel': 24.66759,
#  'soapy': 24.66817,
#  'percs': 24.67046,
#  'caned': 24.67161,
#  'prise': 24.67204,
#  'poxes': 24.67353,
#  'lunes': 24.67366,
#  'shiel': 24.68054,
#  'ratos': 24.6814,
#  'samek': 24.68165,
#  'harts': 24.68464,
#  'toner': 24.68633,
#  'rheas': 24.68858,
#  'bards': 24.68956,
#  'goris': 24.6901,
#  'purse': 24.69049,
#  'deils': 24.69125,
#  'zoeas': 24.69136,
#  'orate': 24.69211,
#  'ments': 24.69245,
#  'roves': 24.69384,
#  'porus': 24.69633,
#  'birse': 24.69701,
#  'laves': 24.69707,
#  'maleo': 24.69711,
#  'almes': 24.70096,
#  'riels': 24.70294,
#  'smite': 24.70353,
#  'shire': 24.7053,
#  'leaks': 24.70768,
#  'barde': 24.70808,
#  'mules': 24.71113,
#  'jeats': 24.71307,
#  'acnes': 24.71742,
#  'stray': 24.71826,
#  'steal': 24.71896,
#  'tosed': 24.72262,
#  'daine': 24.72445,
#  'pirns': 24.72521,
#  'roams': 24.72765,
#  'pedis': 24.72923,
#  'moits': 24.73019,
#  'dopes': 24.73123,
#  'maned': 24.73498,
#  'tinea': 24.73622,
#  'slaty': 24.73924,
#  'calos': 24.74586,
#  'spiel': 24.74666,
#  'jones': 24.749,
#  'cards': 24.75116,
#  'farts': 24.7538,
#  'phase': 24.75485,
#  'nabes': 24.75524,
#  'sepad': 24.75711,
#  'sedan': 24.75758,
#  'beast': 24.75804,
#  'tides': 24.75913,
#  'hoars': 24.76095,
#  'times': 24.76155,
#  'spire': 24.77142,
#  'poley': 24.77321,
#  'nodes': 24.77401,
#  'shape': 24.77417,
#  'nomes': 24.77643,
#  'maxes': 24.78045,
#  'bosey': 24.78311,
#  'prose': 24.78317,
#  'sidey': 24.7844,
#  'bonie': 24.78707,
#  'pitas': 24.79133,
#  'serif': 24.79208,
#  'slave': 24.79286,
#  'porta': 24.79472,
#  'septa': 24.79701,
#  'tiros': 24.79819,
#  'gorse': 24.8034,
#  'dites': 24.80518,
#  'spile': 24.81283,
#  'raids': 24.81338,
#  'mards': 24.81453,
#  'smote': 24.81466,
#  'shore': 24.81643,
#  'brans': 24.81675,
#  'soyle': 24.81958,
#  'hared': 24.82017,
#  'leams': 24.82388,
#  'pesta': 24.82448,
#  'terai': 24.82589,
#  'smear': 24.82741,
#  'senti': 24.828,
#  'suave': 24.83489,
#  'tarps': 24.83502,
#  'brane': 24.83527,
#  'dalis': 24.83602,
#  'pouis': 24.83623,
#  'liars': 24.83773,
#  'mobes': 24.84259,
#  'earst': 24.84395,
#  'cosey': 24.84471,
#  'poena': 24.84715,
#  'pauls': 24.852,
#  'paten': 24.85305,
#  'punas': 24.85389,
#  'shine': 24.85439,
#  'ripes': 24.85628,
#  'faces': 24.85808,
#  'plets': 24.85867,
#  'slide': 24.86064,
#  'veals': 24.86124,
#  'rices': 24.86247,
#  'lenos': 24.86476,
#  'dunes': 24.86774,
#  'foals': 24.87152,
#  'bokes': 24.87482,
#  'tiers': 24.87603,
#  'polts': 24.87681,
#  'crans': 24.87835,
#  'coset': 24.87895,
#  'poral': 24.88148,
#  'spore': 24.88255,
#  'strep': 24.88266,
#  'sepal': 24.88377,
#  'loser': 24.88729,
#  'fared': 24.88933,
#  'crane': 24.89687,
#  'metis': 24.89939,
#  'melos': 24.90223,
#  'stean': 24.90442,
#  'merds': 24.90753,
#  'mosey': 24.90808,
#  'monie': 24.91204,
#  'beisa': 24.91379,
#  'boils': 24.91506,
#  'serer': 24.91726,
#  'spine': 24.92051,
#  'lotas': 24.9227,
#  'loges': 24.92512,
#  'deair': 24.92728,
#  'rozes': 24.92856,
#  'delis': 24.92902,
#  'zones': 24.92969,
#  'realo': 24.93032,
#  'lazes': 24.93179,
#  'noels': 24.93232,
#  'coirs': 24.93525,
#  'cokes': 24.93642,
#  'stela': 24.94204,
#  'ronts': 24.94303,
#  'lants': 24.94626,
#  'belts': 24.95176,
#  'rares': 24.95209,
#  'nails': 24.95268,
#  'shake': 24.95722,
#  'strad': 24.95739,
#  'satin': 24.95832,
#  'parev': 24.95909,
#  'cater': 24.96042,
#  'salon': 24.96116,
#  'ronte': 24.96155,
#  'wries': 24.96249,
#  'peola': 24.96396,
#  'shone': 24.96552,
#  'coste': 24.96683,
#  'perst': 24.96821,
#  'loads': 24.96922,
#  'raree': 24.97061,
#  'voles': 24.97161,
#  'getas': 24.97267,
#  'senas': 24.97656,
#  'coils': 24.97666,
#  'skier': 24.97851,
#  'horis': 24.97871,
#  'orals': 24.98343,
#  'malts': 24.98373,
#  'sises': 24.98419,
#  'parid': 24.98532,
#  'minas': 24.98538,
#  'boner': 24.98595,
#  'pearl': 24.98722,
#  'paiks': 24.99101,
#  'rated': 24.99143,
#  'cause': 24.99308,
#  'baled': 24.99429,
#  'harls': 24.99448,
#  'duras': 24.9945,
#  'staid': 24.99577,
#  'resay': 24.99595,
#  'mokes': 24.99979,
#  'kades': 25.00188,
#  'minae': 25.0039,
#  'socia': 25.00427,
#  'kames': 25.0043,
#  'liane': 25.00534,
#  'poled': 25.01234,
#  'fines': 25.01297,
#  'celts': 25.01336,
#  'smile': 25.01337,
#  'ureas': 25.01355,
#  'blats': 25.01359,
#  'alces': 25.01638,
#  'moire': 25.01714,
#  'sures': 25.02286,
#  'spake': 25.02334,
#  'mater': 25.02379,
#  'speat': 25.02871,
#  'resat': 25.03019,
#  'moste': 25.0302,
#  'blate': 25.03211,
#  'gaits': 25.03397,
#  'wades': 25.03998,
#  'moils': 25.04003,
#  'karos': 25.04094,
#  'slart': 25.04191,
#  'wames': 25.0424,
#  'sarky': 25.04334,
#  ...}

# %%
scorer.calculate_zipf_idf()
# Out:
# {'paris': 22.73482713968794,
#  'pares': 23.493345732936074,
#  'slate': 23.516355161837275,
#  'raise': 23.58849408113198,
#  'mares': 23.85815846499377,
#  'share': 23.8668447795089,
#  'cares': 23.91750574160811,
#  'mores': 24.042018513629284,
#  'bares': 24.087463972610976,
#  'rates': 24.138095691591502,
#  'means': 24.214232517385817,
#  'poles': 24.281752670304844,
#  'saner': 24.597274082761324,
#  'fares': 24.597829363899134,
#  'soare': 24.65726846499377,
#  'stare': 24.691813685511672,
#  'lares': 24.693085104014898,
#  'tales': 24.696567296219136,
#  'pores': 24.719053781622367,
#  'panes': 24.754333720588516,
#  'dares': 24.82501719726605,
#  'siren': 24.83009499999389,
#  'bates': 24.845909106078754,
#  'wares': 24.846548873082693,
#  'bears': 24.99602013941447,
#  'claes': 24.997943041847257,
#  'spare': 25.001274870739536,
#  'seria': 25.005079792650406,
#  'saute': 25.006352101619605,
#  'parse': 25.047098805561685,
#  'spate': 25.17951893966737,
#  'canes': 25.187748451985712,
#  'beats': 25.19898685412125,
#  'tares': 25.246481821636625,
#  'poise': 25.247819059481923,
#  'scale': 25.248248872417435,
#  'tires': 25.25944683676389,
#  'snare': 25.26190914048572,
#  'manes': 25.32843290893039,
#  'sorel': 25.338610377810973,
#  'reais': 25.34065912780636,
#  'bones': 25.381027025317806,
#  'parts': 25.427553017414212,
#  'males': 25.43002750020204,
#  'panel': 25.43964931231358,
#  'pears': 25.456414543522,
#  'saine': 25.507323768614313,
#  'scare': 25.521940652856415,
#  'pines': 25.545804520739022,
#  'coles': 25.562314892470585,
#  'stale': 25.581585579173435,
#  'bores': 25.58676376861431,
#  'gates': 25.589942781188334,
#  'tries': 25.598264176681216,
#  'lanes': 25.63052449648842,
#  'suite': 25.686686433871426,
#  'soler': 25.70121912742733,
#  'boras': 25.70253026681543,
#  'store': 25.71987378220582,
#  'tears': 25.724599858956665,
#  'bales': 25.739010584261038,
#  'solar': 25.75315212666377,
#  'pales': 25.76765720160207,
#  'wales': 25.784621795686448,
#  'sarin': 25.839054085329046,
#  'stage': 25.843536133264305,
#  'nares': 25.87841720160207,
#  'sater': 25.887300439181946,
#  'games': 25.89425485408076,
#  'parte': 25.896010542927975,
#  'times': 25.89834691183513,
#  'banes': 25.91787250955863,
#  'pages': 25.926025621566776,
#  'paste': 25.928295457674523,
#  'safer': 25.93193683441747,
#  'cates': 25.94244211689534,
#  'cores': 25.949393764278295,
#  'plane': 25.95796048106451,
#  'pants': 25.959044338788246,
#  'gores': 25.96304003273309,
#  'paise': 25.993361911015057,
#  'stake': 26.00552782736234,
#  'cause': 26.018312812423126,
#  'roles': 26.02399419261048,
#  'skate': 26.102340185723534,
#  'plate': 26.104107983622978,
#  'saint': 26.12590508810839,
#  'least': 26.14158831939062,
#  'beans': 26.14646990755856,
#  'mates': 26.15748255074684,
#  'hares': 26.17149820333972,
#  'deans': 26.191827495544363,
#  'peris': 26.21424721027411,
#  'since': 26.218692989853285,
#  'tores': 26.229151821636627,
#  'stone': 26.23616083030733,
#  'dales': 26.247262730899372,
#  'party': 26.24943728976703,
#  'later': 26.252963510595304,
#  'pause': 26.265391439718893,
#  'sales': 26.276142688641823,
#  'sonar': 26.27794531642949,
#  'jones': 26.287108270233002,
#  'sarge': 26.31696679842196,
#  'dates': 26.3214848613354,
#  'aeros': 26.32651057992502,
#  'tones': 26.332077197266052,
#  'rales': 26.346823810729614,
#  'sated': 26.347595373104284,
#  'races': 26.358270893766214,
#  'lines': 26.360085315023966,
#  'penis': 26.361947688585797,
#  'poets': 26.378010380330185,
#  'meats': 26.385459357666896,
#  'mines': 26.392642694261177,
#  'sorta': 26.409719132142385,
#  'sared': 26.41397180862857,
#  'pairs': 26.41882149926522,
#  'pates': 26.42282377728635,
#  'ranes': 26.42494180862857,
#  'coats': 26.42629457525136,
#  'teras': 26.42783804446958,
#  'earns': 26.456758043951417,
#  'meals': 26.457884280310594,
#  'slade': 26.475313735855618,
#  'arise': 26.49122963380671,
#  'steal': 26.50166874799866,
#  'money': 26.505908334015846,
#  'saree': 26.506720202092072,
#  'shape': 26.517319488068615,
#  'beals': 26.526324928062458,
#  'carte': 26.527097286750333,
#  'ayres': 26.53080480975517,
#  'saber': 26.537911021585398,
#  'lores': 26.561219127806368,
#  'boles': 26.569615306351928,
#  'miles': 26.57070811616021,
#  'notes': 26.577562013546682,
#  'earls': 26.579121272183045,
#  'dores': 26.579207868750686,
#  'stade': 26.591105138454417,
#  'early': 26.591618257332282,
#  'salet': 26.591870114794297,
#  'score': 26.595275362576487,
#  'ports': 26.59825198228984,
#  'laser': 26.605954950761056,
#  'phase': 26.617313812889797,
#  'morse': 26.63329008806253,
#  'aures': 26.647859796986424,
#  'serai': 26.655913815065635,
#  'corey': 26.676053730232255,
#  'seles': 26.67727637295507,
#  'slide': 26.68505126693531,
#  'shake': 26.697747347314394,
#  'paseo': 26.71305635063531,
#  'space': 26.73541590862059,
#  'arles': 26.74215574594413,
#  'shale': 26.743484165175573,
#  'peats': 26.745090549572886,
#  'deals': 26.748227116164223,
#  'braes': 26.74986845632173,
#  'surge': 26.75750514120756,
#  'paces': 26.76680769378845,
#  'trade': 26.77194012395096,
#  'takes': 26.802530358283605,
#  'saver': 26.816972048031094,
#  'shred': 26.823228890426766,
#  'shore': 26.82720434026905,
#  'smile': 26.85225418539963,
#  'taser': 26.85280247729457,
#  'seres': 26.85740661403102,
#  'makes': 26.874100351840895,
#  'rones': 26.876132891586316,
#  'pones': 26.877930562580943,
#  'sayed': 26.892501987049094,
#  'pareo': 26.8968078730867,
#  'sager': 26.89735865150913,
#  'snake': 26.90779936741395,
#  'tapes': 26.914803459909496,
#  'sored': 26.919520553908907,
#  'sauce': 26.932557012710493,
#  'pleas': 26.932560855705827,
#  'sober': 26.93349597904804,
#  'rules': 26.933921778652262,
#  'acres': 26.935681488611905,
#  'slane': 26.94412125917499,
#  'sabre': 26.95658770091263,
#  'doris': 26.95945934855212,
#  'santo': 26.961153889589948,
#  'solid': 26.96332317178375,
#  'loser': 26.965669854593724,
#  'moles': 26.97158932086934,
#  'peres': 26.993229274656166,
#  'james': 26.997471907310757,
#  'cones': 27.001060575589,
#  'shade': 27.006978512566924,
#  'peaks': 27.013712560345972,
#  'names': 27.028243682014832,
#  'porte': 27.070168644797327,
#  'spite': 27.075937305423203,
#  'vares': 27.093450434845927,
#  'moras': 27.094280562580945,
#  'denis': 27.09542611618456,
#  'lakes': 27.101325119654355,
#  'parks': 27.107112766172026,
#  'cries': 27.118005753654813,
#  'boats': 27.138983912275204,
#  'horse': 27.14505714523105,
#  'blaes': 27.15595251389465,
#  'nears': 27.161684583923396,
#  'large': 27.16822392379235,
#  'coast': 27.16890046419536,
#  'bored': 27.17415487549913,
#  'stair': 27.175983867894047,
#  'reals': 27.176371830308664,
#  'stand': 27.185796371632037,
#  'hales': 27.187681237136143,
#  'shine': 27.194333883947248,
#  'toles': 27.200211834644684,
#  'cures': 27.20392359251638,
#  'pains': 27.21582256901801,
#  'perls': 27.223968220683798,
#  'tired': 27.225133149023833,
#  'fires': 27.24553343599159,
#  'parle': 27.252150562580944,
#  'close': 27.25598795274828,
#  'gares': 27.258551817300607,
#  'slave': 27.264881468411158,
#  'stray': 27.268769596541247,
#  'kaies': 27.276569123470345,
#  'purse': 27.285335068865496,
#  'yates': 27.291295383842858,
#  'cotes': 27.29341107912007,
#  'botes': 27.30405420856063,
#  'ariel': 27.30664839970956,
#  'tarse': 27.314520558244926,
#  'sears': 27.31555479487422,
#  'bared': 27.319218229355833,
#  'pared': 27.33232183464468,
#  'caste': 27.340904123481668,
#  'siler': 27.360565775051377,
#  'sedan': 27.363200909847457,
#  'noise': 27.366131298981394,
#  'rains': 27.367168578352782,
#  'fores': 27.374977005927747,
#  'loris': 27.375126168546373,
#  'worse': 27.377436670101172,
#  'morae': 27.379068451985713,
#  'reads': 27.381150132138373,
#  'hires': 27.397507689452432,
#  'reins': 27.40053468430812,
#  'sayer': 27.40438175697217,
#  'solve': 27.41530462426723,
#  'plans': 27.420453479082088,
#  'posey': 27.422347662558177,
#  'shame': 27.425851900778717,
#  'doles': 27.42904638166939,
#  'spain': 27.432484726010166,
#  'place': 27.435768422556755,
#  'carle': 27.443208651509128,
#  'carse': 27.445291636866653,
#  'pearl': 27.449482523878785,
#  'soave': 27.450938087672615,
#  'canoe': 27.45491860857302,
#  'rapes': 27.479679801322447,
#  'dries': 27.490532207898802,
#  'blues': 27.493402264581874,
#  'senor': 27.50766972146494,
#  'roads': 27.511456948620058,
#  'texas': 27.518119685721633,
#  'apres': 27.519861825972644,
#  'beast': 27.52020791184308,
#  'loans': 27.523949628519258,
#  'crane': 27.524860305650087,
#  'sired': 27.525580549572886,
#  'teams': 27.532488749562937,
#  'heats': 27.53506549739553,
#  'fries': 27.542696111840073,
#  'comes': 27.543283241768755,
#  'cater': 27.55567393376067,
#  'crate': 27.590875634605617,
#  'goals': 27.590989881236972,
#  'super': 27.594171013338155,
#  'pries': 27.597978456321734,
#  'aloes': 27.60723786875068,
#  'mures': 27.61313593259672,
#  'sacre': 27.61404054090085,
#  'route': 27.617423244605746,
#  'carne': 27.619513790661912,
#  'alone': 27.62004749649292,
#  'sable': 27.62196151906639,
#  'chase': 27.625477563915677,
#  'gales': 27.6275518389807,
#  'mires': 27.631412887250296,
#  'smear': 27.642395496541692,
#  'tames': 27.643918451985712,
#  'seral': 27.648201817300606,
#  'spear': 27.650095135637574,
#  'skier': 27.664760821157323,
#  'diane': 27.667482342138253,
#  'patel': 27.67371766205235,
#  'rages': 27.679460420643494,
#  'jeans': 27.68248157526396,
#  'trans': 27.689812067588402,
#  'leads': 27.69443095691922,
#  'raine': 27.700082535574744,
#  'fears': 27.704886303412042,
#  'spray': 27.71650956079955,
#  'hates': 27.72845183464468,
#  'tunes': 27.74410571850783,
#  'years': 27.7490141140486,
#  'rames': 27.7509701147943,
#  'sense': 27.752049200559522,
#  'moats': 27.75431377295033,
#  'soled': 27.765641830308663,
#  'spade': 27.766256183588446,
#  'shear': 27.776279090530796,
#  'cites': 27.77685099382432,
#  'paler': 27.778555952035838,
#  'dames': 27.786828061813658,
#  'ropes': 27.78837661345484,
#  'salty': 27.789312946691112,
#  'saker': 27.79543124580818,
#  'prose': 27.795618978860244,
#  'moais': 27.796868460657752,
#  'mapes': 27.799716701525192,
#  'swear': 27.800133738904293,
#  'baste': 27.818470602722037,
#  'janes': 27.82142839829786,
#  'boast': 27.821448671995416,
#  'rails': 27.82146821201176,
#  'salon': 27.822811810692478,
#  'spine': 27.85303471384284,
#  'lopes': 27.859456020290047,
#  'paire': 27.859675946882412,
#  'ready': 27.868592189045927,
#  'poser': 27.869205744376483,
#  'piles': 27.882993815065635,
#  'slain': 27.883562923400497,
#  'range': 27.886242267476604,
#  'laris': 27.887448948508116,
#  'slope': 27.88845653521457,
#  'wages': 27.900544560555986,
#  'saned': 27.90384180862857,
#  'safed': 27.90433259432448,
#  'peril': 27.90923106588159,
#  'surat': 27.914055040494343,
#  'lears': 27.918441632530634,
#  'piers': 27.91870045408676,
#  'baser': 27.918892160555355,
#  'board': 27.92156440944286,
#  'leans': 27.923843459909495,
#  'saved': 27.92409819313286,
#  'paren': 27.932107868750684,
#  'aisle': 27.935277563620502,
#  'prats': 27.936149180126264,
#  'riles': 27.938559316533322,
#  'stane': 27.944311830308664,
#  'cires': 27.953393768614312,
#  'learn': 27.95821376380988,
#  'plies': 27.964553972610975,
#  'meris': 27.965482891586316,
#  'slake': 27.9679403165056,
#  'slice': 27.9704098089406,
#  'carts': 27.972286957292095,
#  'marse': 27.973193764278292,
#  'stole': 27.98234057992502,
#  'moral': 27.984095694185804,
#  'roast': 27.987236455712083,
#  'snore': 27.99081043365155,
#  'gears': 27.995108868746673,
#  'rites': 28.000726785413903,
#  'false': 28.012190029638095,
#  'cakes': 28.016608482337844,
#  'lures': 28.02064377295033,
#  'soral': 28.02598845632173,
#  'morne': 28.028541108548627,
#  'pomes': 28.034139119134323,
#  'hears': 28.046050835704346,
#  'seamy': 28.047473143345055,
#  'tails': 28.047550084561575,
#  'marts': 28.051169123470345,
#  'sanes': 28.051254721674148,
#  'stead': 28.057690077916664,
#  'louis': 28.057824180386774,
#  'stain': 28.06644234680587,
#  'holes': 28.07560221386187,
#  'faces': 28.077409238064043,
#  'those': 28.07801050817619,
#  'caret': 28.09060008889759,
#  'waste': 28.096384914665105,
#  'mater': 28.097215779387398,
#  'wanes': 28.097402098329322,
#  'clear': 28.101902873821096,
#  'porae': 28.102391808628568,
#  'cards': 28.111927785662274,
#  'teals': 28.117870558244924,
#  'barns': 28.117940080225555,
#  'power': 28.118025563472383,
#  'sates': 28.11851018066954,
#  'toner': 28.119573077363672,
#  'rotes': 28.12706054957289,
#  'seals': 28.13266066355474,
#  'taxes': 28.14377281215998,
#  'sarod': 28.145087951908835,
#  'morel': 28.149901087792106,
#  'codes': 28.15091883851395,
#  'potes': 28.15368180429255,
#  'rines': 28.15633930786128,
#  'aides': 28.1579967854139,
#  'noles': 28.158984473880395,
#  'snead': 28.161613214824712,
#  'cades': 28.162419294853226,
#  'sores': 28.16292821201176,
#  'capes': 28.173039299189245,
#  'caves': 28.182800602722033,
#  'serin': 28.20173377728635,
#  'stave': 28.203682912383908,
#  'blare': 28.20793835343476,
#  'satin': 28.20802427469599,
#  'carns': 28.211183361721023,
#  'coate': 28.222123353048985,
#  'fales': 28.22330008889759,
#  'merit': 28.22444673592525,
#  'manse': 28.226814496488416,
#  'speak': 28.228120343540887,
#  'blase': 28.22954141526571,
#  'peals': 28.23102180862857,
#  'sawer': 28.23192593259672,
#  'bites': 28.23356084794568,
#  'tiles': 28.243235946882407,
#  'relay': 28.248635992935633,
#  'rakes': 28.2538018389807,
#  'samel': 28.256827201602068,
#  'point': 28.262788405732373,
#  'rated': 28.265566170580392,
#  'spore': 28.267726966224277,
#  'chaos': 28.276610517822455,
#  'pelas': 28.290200558244926,
#  'sepia': 28.293432164891374,
#  'colas': 28.295821986625857,
#  'strae': 28.30496180862857,
#  'salve': 28.307988698305333,
#  'spire': 28.312235722843848,
#  'staid': 28.312514712732767,
#  'fates': 28.32275844138084,
#  'monte': 28.324649477519184,
#  'certs': 28.329800119130315,
#  'curse': 28.33289542534184,
#  'sound': 28.337101833199277,
#  'suave': 28.33772108335529,
#  'peans': 28.33870180862857,
#  'swale': 28.346766330624703,
#  'corps': 28.35297222406196,
#  'snail': 28.359740114913706,
#  'perks': 28.363845680574258,
#  'heads': 28.372751471843692,
#  'meads': 28.373299127806362,
#  'senes': 28.379123981283016,
#  'moans': 28.383463357385004,
#  'toeas': 28.38378180862857,
#  'barge': 28.393300249882273,
#  'aegis': 28.394137147914222,
#  'paves': 28.398553768614313,
#  'coria': 28.400992048883335,
#  'cored': 28.403098825505893,
#  'beads': 28.40606037781097,
#  'sandy': 28.407049387672,
#  'corse': 28.40717803094336,
#  'kores': 28.407419303525266,
#  'boers': 28.409557012710493,
#  'water': 28.41660193286867,
#  'prone': 28.427961744832306,
#  'wears': 28.427965517031392,
#  'pager': 28.428513198108305,
#  'coals': 28.43090846499377,
#  'boars': 28.431117951908835,
#  'maire': 28.439960008791346,
#  'mains': 28.446453823572643,
#  'spane': 28.447309132142387,
#  'maser': 28.447370123466335,
#  'darts': 28.451608220683795,
#  'seats': 28.459459165923832,
#  'steam': 28.459777579543818,
#  'motes': 28.465120553908907,
#  'borel': 28.46659661345484,
#  'manet': 28.469709530607442,
#  'beard': 28.472182666288216,
#  'pails': 28.473630553908908,
#  'house': 28.48275133994416,
#  'alien': 28.48479459333314,
#  'paint': 28.4864438489025,
#  'kanes': 28.488650571252983,
#  'marks': 28.490739550306255,
#  'plead': 28.49489132990624,
#  'prate': 28.496592556009954,
#  'poste': 28.51197210266534,
#  'homes': 28.514097688316728,
#  'rouse': 28.516901768784194,
#  'mouse': 28.518134176412353,
#  'rodes': 28.52361180429255,
#  'serac': 28.525707868750686,
#  'samey': 28.527859299189245,
#  'minas': 28.534112356232093,
#  'pyres': 28.535421830308664,
#  'pacer': 28.53577626974343,
#  'dears': 28.54133820767574,
#  'slant': 28.546206433399266,
#  'sloan': 28.548927609690992,
#  'penal': 28.557035503785304,
#  'pater': 28.557346326288684,
#  'rimes': 28.566716297242458,
#  'feats': 28.575810562580944,
#  'melas': 28.578158212011758,
#  'ceros': 28.585963972610976,
#  'shire': 28.586191283116733,
#  'poire': 28.59456146317165,
#  'euros': 28.595388710868285,
#  'antes': 28.595742550746838,
#  'delay': 28.597785771246432,
#  'sweat': 28.60149730630116,
#  'soapy': 28.601546196033595,
#  'prime': 28.602583202286322,
#  'rides': 28.604367789998296,
#  'wires': 28.611370127802353,
#  'sider': 28.625995363647377,
#  'horas': 28.62794787742272,
#  'baile': 28.63069575120808,
#  'aside': 28.633632826292295,
#  'smart': 28.634667631019948,
#  'story': 28.638238766032433,
#  'state': 28.6392860010057,
#  'raves': 28.644933785958386,
#  'smite': 28.663671197752045,
#  'spend': 28.66995865574027,
#  'tines': 28.671869303525263,
#  'cared': 28.6733601147943,
#  'tomes': 28.676073815065635,
#  'cages': 28.682742895922335,
#  'reaps': 28.682862717891318,
#  'tyres': 28.688538469329792,
#  'maker': 28.692924420795322,
#  'manis': 28.70350011045828,
#  'garis': 28.703640074362326,
#  'prise': 28.706120047658356,
#  'monas': 28.709089299189245,
#  'files': 28.71165953944401,
#  'swine': 28.714125798984547,
#  'spiel': 28.717226433866134,
#  'heart': 28.720588627282506,
#  'goats': 28.721508957180152,
#  'shave': 28.724421780823487,
#  'hades': 28.725708026607343,
#  'trace': 28.725889936780735,
#  'pures': 28.73037180862857,
#  'manos': 28.733070667890757,
#  'amies': 28.736387005927746,
#  'coral': 28.742233405105186,
#  'toras': 28.748871808628568,
#  'sease': 28.75212008889759,
#  'fanes': 28.754009299189242,
#  'spier': 28.75570256034597,
#  'conte': 28.75697359760959,
#  'south': 28.76362168638238,
#  'maces': 28.76547804446958,
#  'satem': 28.767432891586317,
#  'daris': 28.76876054957289,
#  'leafs': 28.768907823478564,
#  'media': 28.770158754821708,
#  'beams': 28.77517518359246,
#  'cafes': 28.776334688644138,
#  'death': 28.77671708437186,
#  'reans': 28.78920180862857,
#  'kales': 28.790743815065635,
#  'loner': 28.793231035454895,
#  'stoke': 28.793809485078167,
#  'taros': 28.79450180429255,
#  'price': 28.800594338985025,
#  'samen': 28.802902887250298,
#  'dunes': 28.80383661779086,
#  'slier': 28.803853768614314,
#  'copes': 28.808921812964588,
#  'nurse': 28.814091065374228,
#  'salas': 28.814500108488836,
#  'nails': 28.816405919350636,
#  'polis': 28.828769127806368,
#  'pokes': 28.832483968274957,
#  'colts': 28.833356335589045,
#  'bayes': 28.836207005927747,
#  'miner': 28.844963872370187,
#  'train': 28.845284264054175,
#  'irate': 28.84762590594631,
#  'table': 28.851996795590537,
#  'botas': 28.85411821201176,
#  'terns': 28.85627251389465,
#  'terai': 28.861438086741522,
#  'borne': 28.86385757512225,
#  'goles': 28.866173459909493,
#  'poems': 28.866526892490086,
#  'naris': 28.867918044469583,
#  'blame': 28.868627646783125,
#  'rents': 28.871988952844134,
#  'carve': 28.872114153070893,
#  'neals': 28.873509127806365,
#  'pinas': 28.87445043484593,
#  'spree': 28.877277938454974,
#  'polar': 28.879968322603773,
#  'vales': 28.88556197795382,
#  'based': 28.885831241472165,
#  'flies': 28.888657907685563,
#  'marle': 28.889442891586317,
#  'saice': 28.890311817300606,
#  'rinse': 28.89569648066276,
#  'bries': 28.898390558244927,
#  'strew': 28.901160521337644,
#  'mairs': 28.905510123466335,
#  'wines': 28.90730804024984,
#  'maile': 28.912733772950332,
#  'liars': 28.917621821636626,
#  'haste': 28.920367674157553,
#  'tides': 28.923226394034558,
#  'carls': 28.92405846065775,
#  'porta': 28.924612278776706,
#  'bines': 28.92573181296459,
#  'seron': 28.932542887250296,
#  'trail': 28.938193200039777,
#  'prase': 28.939201821636626,
#  'gains': 28.93920506424076,
#  'sneak': 28.940161503116236,
#  'grate': 28.9402287767462,
#  'salto': 28.940327012710494,
#  'bakes': 28.94571288291428,
#  'seton': 28.94688502497856,
#  'biles': 28.948283976946996,
#  'manie': 28.948563981283016,
#  'costa': 28.95194072680819,
#  'stein': 28.952370321170058,
#  'coney': 28.953150696540625,
#  'sonde': 28.95593786875068,
#  'cents': 28.956923373817187,
#  'strep': 28.962551821636627,
#  'dines': 28.963202882914278,
#  'earth': 28.96569518557402,
#  'mired': 28.96937254179338,
#  'meaty': 28.97042228744874,
#  'cames': 28.972953768614314,
#  'reams': 28.975863768614314,
#  'snarl': 28.980484520514427,
#  'alter': 28.98049017738101,
#  'pacos': 28.98162432944156,
#  'vanes': 28.985581817300606,
#  'laces': 28.98734930786128,
#  'piste': 28.998939966310896,
#  'toney': 29.00429304777785,
#  'moves': 29.004793965966066,
#  'heals': 29.01485821634778,
#  'bowes': 29.01570761402701,
#  'seric': 29.01684256034597,
#  'taper': 29.01898294290717,
#  'raids': 29.01966062464016,
#  'rants': 29.0242637162525,
#  'carol': 29.02660604414767,
#  'force': 29.026979679655717,
#  'burns': 29.041018032803535,
#  'padre': 29.041121472397215,
#  'maise': 29.04125845632173,
#  'pride': 29.052775090005074,
#  'stoae': 29.05403180862857,
#  'lapse': 29.054538792938693,
#  'teary': 29.059093288802337,
#  'fades': 29.059328819642666,
#  'votes': 29.064796082856724,
#  'zones': 29.066953790661913,
#  'cines': 29.084241825972644,
#  'sadly': 29.085908058457214,
#  'solei': 29.089410553908905,
#  'sidle': 29.089763261724187,
#  'tamer': 29.09477515658966,
#  'perts': 29.09597180862857,
#  'modes': 29.105796952956076,
#  'noris': 29.10586054957289,
#  'sires': 29.108222556009952,
#  'smoke': 29.109003406340026,
#  'stile': 29.109188829841912,
#  'forte': 29.10937855277731,
#  'phone': 29.10983559991338,
#  'cameo': 29.11046233855391,
#  'torse': 29.121099299189243,
#  'strap': 29.124718088885487,
#  'posed': 29.126787956244854,
#  'spike': 29.13119301590018,
#  'bails': 29.137220558244927,
#  'roues': 29.138881812964588,
#  'caner': 29.139376789749917,
#  'sawed': 29.142391821636625,
#  'trial': 29.142787342988974,
#  'renos': 29.14583846499377,
#  'palis': 29.147129123470343,
#  'mages': 29.14725804446958,
#  'peons': 29.14861845632173,
#  'crans': 29.154614026291814,
#  'shier': 29.159279796986425,
#  'laden': 29.15940422591364,
#  'mosey': 29.160279532962182,
#  'puris': 29.163972461532836,
#  'daily': 29.173103072327073,
#  'danse': 29.18253382373767,
#  'spaer': 29.18352180862857,
#  'hones': 29.190398044469582,
#  'leaks': 29.202111092128128,
#  'likes': 29.205441129834597,
#  'swire': 29.20969497529996,
#  'feast': 29.211380556610532,
#  'marge': 29.218058288895836,
#  'great': 29.219450696805225,
#  'baker': 29.219901272183044,
#  'brake': 29.225255157501255,
#  'petar': 29.226273819236624,
#  'lords': 29.230961896232344,
#  'doats': 29.237211825972643,
#  'fines': 29.24390336080913,
#  'riley': 29.254523382489225,
#  'model': 29.258417729912555,
#  'beira': 29.262507289930824,
#  'metas': 29.27126179995653,
#  'runes': 29.272801799956532,
#  'coins': 29.273531423937754,
#  'gorse': 29.274498447649695,
#  'norie': 29.2751659433638,
#  'sitar': 29.275468280223798,
#  'sower': 29.278407008374476,
#  'moran': 29.27953336698655,
#  'roate': 29.27987180862857,
#  'brace': 29.28027563907496,
#  'armed': 29.28297738843968,
#  'warns': 29.283343716052993,
#  'soree': 29.284110553908906,
#  'strip': 29.293574479886082,
#  'bonus': 29.296005110481882,
#  'dalis': 29.29655757512225,
#  'ranis': 29.300499299189244,
#  'soles': 29.300891463171652,
#  'lites': 29.30404719726605,
#  'paned': 29.30615251389465,
#  'soars': 29.308256644293863,
#  'snipe': 29.308281495780985,
#  'hopes': 29.32301064218963,
#  'buras': 29.324850074362324,
#  'bread': 29.325364921417545,
#  'boite': 29.32796820767574,
#  'react': 29.331045495855676,
#  'steak': 29.3324037051832,
#  'payer': 29.333578895611186,
#  'piano': 29.33378587569938,
#  'peaty': 29.33598180862857,
#  'oared': 29.336089123470344,
#  'scary': 29.33977500432991,
#  'metal': 29.342490239648953,
#  'geats': 29.342979299189246,
#  'clues': 29.346310789827655,
#  'pulse': 29.346743962879543,
#  'orate': 29.348755947699818,
#  'leats': 29.35758180862857,
#  'slime': 29.359294850519635,
#  'singe': 29.359322452661292,
#  'loves': 29.361909014510452,
#  'baler': 29.361941636866653,
#  'toile': 29.364088777648675,
#  'saris': 29.36712533748099,
#  'snide': 29.368099294969504,
#  'hames': 29.370121977953822,
#  'bosie': 29.373537005927744,
#  'bayer': 29.37466629612236,
#  'stear': 29.37748720160207,
#  'nates': 29.377770553908906,
#  'plant': 29.379591401461266,
#  'toads': 29.38146125917499,
#  'celts': 29.386747399403347,
#  'leary': 29.387020621240758,
#  'stipe': 29.39188246619587,
#  'bodes': 29.394279127806364,
#  'cased': 29.40291057125298,
#  'riots': 29.413601364958225,
#  'ramis': 29.414120411971457,
#  'pareu': 29.421083772950333,
#  'brats': 29.427969299189243,
#  'tours': 29.42836242145728,
#  'neats': 29.428970553908908,
#  'leaps': 29.432064847236038,
#  'scrae': 29.432811808628568,
#  'style': 29.435667610564863,
#  'zaire': 29.437319775259592,
#  'cadet': 29.4403506837778,
#  'mites': 29.447931259174986,
#  'cokes': 29.451054478216413,
#  'today': 29.452262577178377,
#  'peart': 29.453960377810972,
#  'segar': 29.456873819401654,
#  'dures': 29.457761821636627,
#  'stern': 29.46114766888892,
#  'tiare': 29.465771817300606,
#  'heros': 29.468850512972807,
#  'deros': 29.472770562580944,
#  'moers': 29.473421830308663,
#  'waite': 29.476008636025533,
#  'blade': 29.477425851059305,
#  'molas': 29.479410084561575,
#  'flare': 29.480037657889504,
#  'boxes': 29.482829110462287,
#  'blast': 29.48369653914638,
#  'bolas': 29.49127804446958,
#  'sones': 29.492219119134326,
#  'cadre': 29.496771125192353,
#  'siree': 29.498060084561573,
#  'tread': 29.502657245104913,
#  'scone': 29.504660136474392,
#  'spale': 29.505960553908906,
#  'pelts': 29.507723810729615,
#  'haves': 29.50897427646989,
#  'stire': 29.511041817300608,
#  'perns': 29.51349180862857,
#  'biers': 29.51419321916073,
#  'lewis': 29.514207339159498,
#  'fared': 29.514376961628116,
#  'anise': 29.516457481835218,
#  'baron': 29.51657553581876,
#  'pikes': 29.517876295214005,
#  'cable': 29.521330373625226,
#  'caser': 29.523179299189245,
#  'ponts': 29.526121801983656,
#  'scope': 29.527570243068183,
#  'lions': 29.534832626935245,
#  'motel': 29.538964331476407,
#  'banks': 29.542568542266764,
#  'betas': 29.54423180862857,
#  'pauls': 29.54494719726605,
#  'douse': 29.545457649191373,
#  'shiel': 29.546250512972804,
#  'solan': 29.546329294853226,
#  'aired': 29.546340084561574,
#  'short': 29.54806130036544,
#  'coste': 29.550138087147534,
#  'layer': 29.551332590489846,
#  'camel': 29.555515410661343,
#  'terms': 29.55607526675061,
#  'cover': 29.557508580290172,
#  'eases': 29.557828627353494,
#  'plain': 29.55872374037907,
#  'realm': 29.562583176173167,
#  'salue': 29.563751812964586,
#  'caper': 29.565314434326552,
#  'lomas': 29.567699109565087,
#  'robes': 29.573697951908834,
#  'raile': 29.57467376861431,
#  'monie': 29.579051463171652,
#  'cains': 29.57950183030866,
#  'auris': 29.585753976946993,
#  'yales': 29.591759299189246,
#  'mails': 29.59318377728635,
#  'roils': 29.605770558244924,
#  'taels': 29.61272180862857,
#  'mules': 29.61856484723604,
#  'liner': 29.61912343310562,
#  'write': 29.619675003763525,
#  'dance': 29.621155983351912,
#  'delta': 29.621515459813587,
#  'clean': 29.62169216496951,
#  'tenia': 29.624327522929015,
#  'sited': 29.624683810729614,
#  'beaus': 29.625229299189243,
#  'shite': 29.627460119130316,
#  'selah': 29.630388948508113,
#  'degas': 29.63131011529967,
#  'serif': 29.632047008374474,
#  'harts': 29.634198053141624,
#  'trois': 29.642073466954486,
#  'shard': 29.6426113089806,
#  'rainy': 29.643722855520387,
#  'rials': 29.645772887250295,
#  'grade': 29.64833985041652,
#  'aeons': 29.649871812964587,
#  'baits': 29.651289299189244,
#  'perai': 29.652510114794296,
#  'glare': 29.653628093282713,
#  'metis': 29.654485104014896,
#  'yores': 29.65452180862857,
#  'curie': 29.658459543615496,
#  'sured': 29.65977180862857,
#  'ferns': 29.661841079120073,
#  'taker': 29.66625522521867,
#  'radio': 29.667156639490152,
#  'duras': 29.669985770715357,
#  'liane': 29.674454588259415,
#  'malis': 29.676051817300607,
#  'belts': 29.677063233759384,
#  'roans': 29.678871808628568,
#  'brain': 29.682171413507813,
#  'coned': 29.686410349740022,
#  'movie': 29.686965813203717,
#  'fones': 29.69092180862857,
#  'morts': 29.695020566916966,
#  'sport': 29.69828643936711,
#  'spice': 29.700900700005263,
#  'waits': 29.70361360498526,
#  'domes': 29.70601180429255,
#  'renal': 29.707527441239606,
#  'boral': 29.713804217232667,
#  'sined': 29.714420553908905,
#  'sorda': 29.716729123470344,
#  'gades': 29.71829377728635,
#  'brane': 29.721341795620514,
#  'vines': 29.72397195838111,
#  'ratio': 29.725992368792106,
#  'piney': 29.726576954252447,
#  'tried': 29.72852087994417,
#  'petal': 29.728555145670153,
#  'palet': 29.728580562580945,
#  'daine': 29.73430395502887,
#  'cease': 29.738017697459746,
#  'parti': 29.74232328880234,
#  'sites': 29.74884516255694,
#  'syren': 29.750612891586314,
#  'scrap': 29.753616465280533,
#  'roset': 29.754732891586315,
#  'carpe': 29.758409114798305,
#  'diner': 29.76032746762312,
#  'ranse': 29.765981817300606,
#  'tynes': 29.768930547263995,
#  'bolts': 29.770949203703115,
#  'taces': 29.772251808628567,
#  'beaty': 29.77297190775723,
#  'plats': 29.776679303525263,
#  'benis': 29.782680562580943,
#  'tarns': 29.784461812964587,
#  'moire': 29.785277960580874,
#  'telos': 29.788523950692856,
#  'wiles': 29.789008732032837,
#  'spaed': 29.790251808628568,
#  'setal': 29.790573768614312,
#  'taler': 29.79216820767574,
#  'sonic': 29.793885998093998,
#  'sharp': 29.795742658075454,
#  'hotel': 29.80147559531236,
#  'lenis': 29.802162891586317,
#  'tared': 29.803501808628567,
#  'lower': 29.81289619842633,
#  'savor': 29.81372891857421,
#  'scant': 29.815710586496866,
#  'fails': 29.81650544680553,
#  'surly': 29.817839863292683,
#  'louie': 29.8232671162488,
#  'saves': 29.82724498606924,
#  'ceres': 29.8278174774992,
#  'girls': 29.82813426193719,
#  'basin': 29.828833407332226,
#  'tunas': 29.829773950692854,
#  'salep': 29.83002180862857,
#  'sugar': 29.845471912093252,
#  'honey': 29.8465945102773,
#  'maple': 29.848680137182825,
#  'sorex': 29.849481812964587,
#  'spred': 29.851098456321733,
#  'risen': 29.85129365606764,
#  'noire': 29.852866296188378,
#  'fairs': 29.857821973617803,
#  'boils': 29.860615310687947,
#  'broad': 29.86110569377695,
#  'spied': 29.862619119134326,
#  'maids': 29.863742976819886,
#  'screw': 29.866280974827202,
#  'sidey': 29.869754717338132,
#  'goris': 29.87374125917499,
#  'gapes': 29.875041817300605,
#  'selva': 29.87508584467543,
#  'tased': 29.877833768614313,
#  'porey': 29.882041808628568,
#  'boney': 29.88474537310428,
#  'faire': 29.88497062464016,
#  'bases': 29.886749398317907,
#  'cosey': 29.893193357385,
#  'spake': 29.895732098329322,
#  'shone': 29.903178829841913,
#  'drape': 29.90444445218879,
#  'tower': 29.90467604182746,
#  'septa': 29.90493054523687,
#  'voles': 29.905373785958385,
#  'dimes': 29.907238083336594,
#  'barks': 29.907974855368902,
#  'aunes': 29.90858180862857,
#  'bonds': 29.909275704026467,
#  'baels': 29.912341808628568,
#  'after': 29.912491540698216,
#  'tesla': 29.915423994291075,
#  'hails': 29.91730126300518,
#  'boner': 29.919713785958386,
#  'seine': 29.922325970376004,
#  'senti': 29.92449108345609,
#  'preta': 29.925580027129843,
#  'byres': 29.926010562580945,
#  'break': 29.928025899568812,
#  ...}

# %%
# inv_index.print_index()

# %%
# inv_index.index(words_list)

# %%
words_list = inv_intersect.get_intersection('pares', res, inv_index.index(words_list), game.get_wordle_words())

# %%
words_list
# Out:
# ['peace',
#  'peach',
#  'peage',
#  'peake',
#  'peaky',
#  'peare',
#  'pearl',
#  'peart',
#  'pease',
#  'peasy',
#  'peaty',
#  'peavy',
#  'peaze',
#  'pecan',
#  'pecia',
#  'pedal',
#  'pegma',
#  'pekan',
#  'pekau',
#  'pelau',
#  'pelma',
#  'pelta',
#  'penal',
#  'penna',
#  'peola',
#  'pepla',
#  'pesta',
#  'petal',
#  'petar',
#  'phage',
#  'phang',
#  'phare',
#  'pharm',
#  'phase',
#  'phasm',
#  'phial',
#  'phoca',
#  'phota',
#  'phwat',
#  'phyla',
#  'phyma',
#  'physa',
#  'piani',
#  'piano',
#  'pibal',
#  'pical',
#  'picra',
#  'pieta',
#  'pikau',
#  'pilae',
#  'pilaf',
#  'pilao',
#  'pilar',
#  'pilau',
#  'pilaw',
#  'pinax',
#  'pinda',
#  'pinga',
#  'pinna',
#  'pinta',
#  'pipal',
#  'pitta',
#  'piuma',
#  'pizza',
#  'place',
#  'plack',
#  'plaga',
#  'plage',
#  'plaid',
#  'plaig',
#  'plain',
#  'plait',
#  'planc',
#  'plane',
#  'planh',
#  'plank',
#  'plant',
#  'plash',
#  'plasm',
#  'plast',
#  'plate',
#  'platt',
#  'platy',
#  'plaud',
#  'plaur',
#  'playa',
#  'plaza',
#  'plead',
#  'pleat',
#  'plena',
#  'plica',
#  'ploat',
#  'poach',
#  'poaka',
#  'poake',
#  'poalo',
#  'pocan',
#  'podal',
#  'podia',
#  'poena',
#  'pokal',
#  'polar',
#  'polka',
#  'pompa',
#  'ponga',
#  'pooay',
#  'pooja',
#  'pooka',
#  'poopa',
#  'popia',
#  'poppa',
#  'posca',
#  'potae',
#  'potai',
#  'powan',
#  'praam',
#  'prahu',
#  'prana',
#  'prang',
#  'prank',
#  'prase',
#  'prate',
#  'pratt',
#  'praty',
#  'prawn',
#  'preak',
#  'presa',
#  'preta',
#  'prial',
#  'prian',
#  'prima',
#  'proal',
#  'prora',
#  'pruta',
#  'pryan',
#  'psalm',
#  'pshaw',
#  'psoae',
#  'psoai',
#  'psora',
#  'pucan',
#  'pucka',
#  'puffa',
#  'pujah',
#  'pukka',
#  'pulao',
#  'pulka',
#  'punga',
#  'punka',
#  'pupae',
#  'pupal',
#  'puppa',
#  'putza',
#  'puzta',
#  'pygal',
#  'pzazz']

# %%
scorer.recompute_scoring(words_list)
scorer.get_best_guess(scoring_method='zipf_idf')
# Out:
# ['plane']

# %%
res = game.guess('pelta')

# %%
words_list = inv_intersect.get_intersection('pelta', res, inv_index.index(words_list), game.get_wordle_words())

# %%
len(words_list)
# Out:
# 66

# %%
scorer.recompute_scoring(words_list)
scorer.get_best_guess()
# Out:
# 'plane'

# %%
res = game.guess('plane')

# %%
words_list = inv_intersect.get_intersection('plane', res, inv_index.index(words_list), game.get_wordle_words())

# %%
len(words_list)
# Out:
# 10

# %%
scorer.recompute_scoring(words_list)
scorer.get_best_guess()
# Out:
# 'plaid'

# %%
res = game.guess('plaid')

# %%
words_list = inv_intersect.get_intersection('plaid', res, inv_index.index(words_list), game.get_wordle_words())

# %%
len(words_list)
# Out:
# 3

# %%
scorer.recompute_scoring(words_list)
scorer.get_best_guess()
# Out:
# 'plaig'

# %%
#openai api

# %%
import openai

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
openai.api_key = os.environ.get('OPENAI_API_KEY')

# %%
openai.api_key
# Out:
# 'sk-proj-U0tZRYm5gmCLVd8d69yhT3BlbkFJRcmmQJ0IoTsa29VP7xIq'

# %%
prompt_one = "You are a strategic assistant that loves words and probability "

# %%
prompt_two = f'''Given the previous Wordle solutions delimited by backticks,\ 
```{input()}, {input()}, {input()} ```, what is the most\
helpful best first guess for tomorrows game? Please explain why this is \
the best choice and enclose the guess in square brackets'''
# Out:
# hello
# tasks
# macks

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": prompt_one},
      {"role": "user", "content": prompt_two}
  ]
)
variable = (completion.choices[0].message.content)

# %%
import re

# %%
best_guess = re.findall(r"\[(\w{1,5})\]", variable)[0]

# %%
best_guess
# Out:
# 'brake'

# %%
import openai
from openai import OpenAI
from dotenv import load_dotenv
import os
import re

class ChatGPTClient:
	def __init__(self, api_key):
		openai.api_key = api_key
		self.client = OpenAI()


	def get_completion(self, sys_prompt, *user_inputs, engine="gpt-3.5-turbo"):
		input_str = ', '.join([f'"{inp}' for inp in user_inputs])
		prompt = f"{sys_prompt}\n```{input_str}```"
		completion = self.client.chat.completions.create(
			model=engine,
			messages=[
				{"role": "system", "content": "You are a strategic assistance that loves words and probability."},
				{"role": "user", "content": prompt}
			]
		)
		return (completion.choices[0].message.content)

def main():
	load_dotenv()
	api_key = os.environ.get('OPENAI_API_KEY') # Retrieve the API key from the .env
	gpt = ChatGPTClient(api_key)
	prompt= "Given the previous Wordle solutions delimited by backticks\
			what is the most helpful starting word for the next game?\
			Please explain why this is the best choice and enclose the\
			guess in square brackets."
	prev_one=input("Enter yesterday's Wordle solution: ")
	prev_two=input("Enter the previous Wordle solution: ")
	prev_three=input("Enter the Wordle solution before: ")

	print(gpt.get_completion(prompt, prev_three, prev_two, prev_one))
# 	best_guess = re.findall(r"\[(\w{1,5})\]", completion)[0]
# 	print(best_guess)

if __name__ == '__main__':
	main()
# Out:
# Enter yesterday's Wordle solution: value
# Enter the previous Wordle solution: vagye
# Enter the Wordle solution before: title
# [The most helpful starting word for the next Wordle game would be "teary." This word is a great choice because it contains a good mix of common vowels and consonants, which can help to quickly eliminate various possibilities and narrow down the potential solutions. Additionally, "teary" has a balanced distribution of letters, making it a versatile starting point for deducing the target word. Overall, "teary" provides a strong foundation for efficiently solving the Wordle puzzle.]
